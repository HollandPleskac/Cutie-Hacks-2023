# %%
import math
import random

Grade_level = ['Grade', 'Middle', 'Highschool']
user_input = input('What is your current grade level? Grade, Middle, or Highschool?: ')

if user_input != ('Grade' or 'Middle' or 'Highschool'):  #Checks if user inputed within parameters
    print('Invald Grade level')
    user_input = input('What is your current grade level? Grade, Middle, or Highschool?: ')
   
if user_input == "Grade":      #This is the Grade Branch
    GCourse = input('What would you like to study? English, Math, or Physics?: ')
    if GCourse == 'Physics':
        PhyTopic_g = input('Which topic in Physics would you like to learn about? Kinetic Energy, Potential Energy, Newtons 2nd Law:')
        if PhyTopic_g == 'Kinetic Energy':   
            while True:      #Practice Problem with KE
                m = random.randint(1,5)
                v = random.randint(1,10)
                KE = (0.5)*(m)*(v*v)
                Practice = input('Would you like a practice problem?: Yes or No')
                if Practice == 'Yes': 
                    print(f'There is a little ball flying in the air that weights, m = {m}, going at speed, v = {v} \n what will be the kinetic energy of the ball? *Round to the nearest number*:')
                    Solution = int(input())
                    if Solution == KE:
                        print('Fantasic Job!')
                    elif Solution != KE:
                        print("Answer is wrong, try again")
                elif Practice == 'No':                   
                    break
        elif PhyTopic_g == "Potential Energy":
            while True:        #Practice Problem For PE
                m = random.randint(1,5)
                h = random.randint(1,10)
                g = 10
                PE = m*g*h
                Practice = input('Would you like a practice problem?: Yes or No')
                if Practice == 'Yes': 
                    print(f'There is a plate ontop of a {h}meter tall table, if the plate weighs {m}kg. \nWhat is the potential energy of the plate? *Round to the nearest number*:')
                    Solution = int(input())
                    if Solution == PE:
                        print('Fantasic Job!')
                    elif Solution != PE:
                        print("Answer is wrong, try again")
                elif Practice == 'No':
                    break
        elif PhyTopic_g == "Newtons 2nd Law":
            while True:       # Practice Problem for Newton
                m = random.randint(1,5)
                a = random.randint(1,10)
                F = m*a
                Practice = input('Would you like a practice problem?: Yes or No')
                if Practice == 'Yes': 
                    print(f'There is a lil toy rocket that weighs m = {m}, and it is launching for the moon with an acceleration of, a = {a}. \nHow much Force is being produced? *Round to the nearest number*:')
                    Solution = int(input())
                    if Solution == F:
                        print('Fantasic Job!')
                    elif Solution != F:
                        print("Answer is wrong, try again")
                elif Practice == 'No':
                    break
elif user_input == 'Middle':
    MCourse = input('What would you like to study? English, Math, or Physics?: ')
    if MCourse == 'Physics':
        PhyTopic_m = input('Which topic in Physics would you like to learn about? Kinetic Energy, Potential Energy, Newtons 2nd Law:')
        if PhyTopic_m == 'Kinetic Energy':
            while True: # #Practice Problem with KE
                m = random.randint(40,80)
                v = random.randint(1,20)
                KE = (0.5)*(m)*(v*v)
                Practice = input('Would you like a practice problem?: Yes or No')
                if Practice == 'Yes': 
                    print(f'There is a lion with speed {v}m/s and it has a mass of {m}kg, as it is chasing a zebra for its meal. \n What will be the kinetic energy of the lion at an cetaint insant during its chase? *Round to the lowest number and include Units*:')
                    Solution = (input())
                    if Solution == (f'{int(KE)}N'):
                        print('Fantasic Job!')
                    elif Solution != (f'{int(KE)}N'):
                        print("Answer is wrong, try again")
                elif Practice == 'No':
                    break
        elif PhyTopic_m == "Potential Energy":
            while True:   #Practice Problem with PE
                m = random.randint(5,20)
                h = random.randint(10,80)
                g = 9.81
                PE = m*g*h
                Practice = input('Would you like a practice problem?: Yes or No')
                if Practice == 'Yes': 
                    print(f'There is an biplane gliding over at altitude, {h}m, it is prepared to drop a bucket of water of mass, {m}kg on a small fire. \nWhat is the potential energy of the bucket full of water as it hits the ground? *Round to the lowest number and inlcude units*:')
                    Solution = (input())
                    if Solution == (f'{int(PE)}N'):
                        print('Fantasic Job!')
                    elif Solution != (f'{int(PE)}N'):
                        print("Answer is wrong, try again")
                elif Practice == 'No':
                    break
        elif PhyTopic_m == "Newtons 2nd Law":
            while True: #Newtons 2nd Law Middle
                m = random.randint(1,5)
                F = random.randint(12, 35)
                a = (F // m)
                Practice = input('Would you like a practice problem?: Yes or No')
                if Practice == 'Yes': 
                    print(f'Suppose there is a boy applies a force, F = {F}N, to his friend on a swing who has mass, m = {m}Kg \nIF we know the force of the interaction then what is the tangental acceleration of the boy on the swing? *Round to the lowest number and include units*:')
                    Solution = (input())
                    if Solution == (f'{int(a)}m/s**2'):
                        print('Fantasic Job!')
                    elif Solution != (f'{int(a)}m/s**2'):
                        print("Answer is wrong, try again")
                elif Practice == 'No':
                    break
elif user_input == "High": # Branch for the Highschool
    HCourse = input('What would you like to study? English, Math, or Physics?: ')
    if HCourse == 'Physics':
        PhyTopic_h = input('Which topic in Physics would you like to learn about? Kinetic Energy, Potential Energy, Newtons 2nd Law:')
        if PhyTopic_h == 'Kinetic Energy':
            while True: # Practice Problem high KE
                m = random.randint(1,3)
                vi = random.randint(0,49)
                vf = random.randint(50,107)
                KE = (0.5*m*vf**2)-(0.5*m*vi**2)
                Practice = input('Would you like a practice problem?: Yes or No')
                if Practice == 'Yes': 
                    print(f'A Peregrine falcon spots a prey when its speed is, {vi}m/s, it locks in and begins to gain altitude for a dive. When it is ready it begins to dive and reaches a speed of {vf}m/s as it collides with its prey, if the mass is then {m}Kg, what will be the Total Kinetic Energy of the Falcon at impact? *Round to the lowest number and include Units*:')
                    Solution = (input())
                    if Solution == (f'{int(KE)}N'):
                        print('Fantasic Job!')
                    elif Solution != (f'{int(KE)}N'):
                        print("Answer is wrong, try again")
                elif Practice == 'No':
                    break
        elif PhyTopic_h == "Potential Energy":
            while True: #PE high
                m = random.randint(5,20)
                h1 = random.randint(50,100)
                h2 = random.randint(0,49)
                g = 9.81
                PE = (m*g)*(h1)-(m*g)*(h2)
                Practice = input('Would you like a practice problem?: Yes or No')
                if Practice == 'Yes': 
                    print(f'You launch a toy rocket from the top of a build, {h1}m, as you launch it you realize you forgot to take the angle so you wont be able to determine the distance anymore. In hopes of salving the experiment you remeber that you knew its mass and the height of the building youre at. If the rocket weigh, {m}Kg, \n What would be its potential energy at a height {h2}m? *Round to the lowest number and inlcude units*:')
                    Solution = (input())
                    if Solution == (f'{int(PE)}N'):
                        print('Fantasic Job!')
                    elif Solution != (f'{int(PE)}N'):
                        print("Answer is wrong, try again")
                elif Practice == 'No':
                    break
        elif PhyTopic_h == "Newtons 2nd Law":
            while True:      # Practice Problem for Newton
                m = random.randint(1,5)
                a = random.randint(1,10)
                F = m*a
                x = random.randint(1,3)
                K = (2*m*a) //(x*x) 
                Practice = input('Would you like a practice problem?: Yes or No')
                if Practice == 'Yes': 
                    print(f'There is a spring with force, F = {F}N, released from equilibrium, that travels a distance x = {x}. \nWhat is the spring constant, K? *Round to the lowest number and include Units*:')
                    Solution = (input())
                    if Solution == (f'{int(K)}N/m'):
                        print('Fantasic Job!')
                    elif Solution != (f'{int(K)}N/m'):
                        print("Answer is wrong, try again")
                elif Practice == 'No':
                    break
